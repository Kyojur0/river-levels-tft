# %% [markdown]
# # Interpretability
#
# The figure is generated from PyTorch Forecasting `interpret_output` reductions saved by the real Kingston TFT smoke run. These are descriptive diagnostics, not causal effects.

# %%
from pathlib import Path
from src.interpretability import plot_interpretation

plot_interpretation(
    Path('../results/river_one_station_tft.json'),
    Path('../reports/figures/tft_interpretability.png'),
)

# %%
from IPython.display import Image, display
display(Image(filename='../reports/figures/tft_interpretability.png'))
